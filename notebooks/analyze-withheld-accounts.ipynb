# %% [markdown]
# # Analyzing Twitter API data of "withheld" accounts

# %% [markdown]
# ## Step 1: Load the data we've collected on withheld accounts

# %%
import pandas as pd

# %%
accounts = pd.read_csv("../data/withheld-accounts.csv")
len(accounts)
# Out:
# 1714

# %%
accounts.head().T
# Out:
#                                                                        0  \
# user_id_numfix                                                 '14613185
# user_id                                                         14613185
# screen_name                                                  iEvolutiOne
# bio                    Gab- iEvolutiOne #Anon3R #G8Links #AntiGentili...
# withheld_category                                               withheld
# withheld_in_countries                                                 DE
# withheld_ever                                                         DE
# followers_count                                                     8738
# following_count                                                     8894
# signup_date                                                   2008-05-01
# first_observed                                                2017-10-02
#
#                                                                        1  \
# user_id_numfix                                                 '17232910
# user_id                                                         17232910
# screen_name                                                    sechapman
# bio                    #SouthernPresbyterians My only allegiances are...
# withheld_category                                           not_withheld
# withheld_in_countries                                                NaN
# withheld_ever                                                         DE
# followers_count                                                     1659
# following_count                                                     3223
# signup_date                                                   2008-11-07
# first_observed                                                2017-10-02
#
#                                                                        2  \
# user_id_numfix                                                 '19063025
# user_id                                                         19063025
# screen_name                                              sondakika_haber
# bio                    Bizi takip edin haberiniz olsun! #SonDakika #H...
# withheld_category                                               withheld
# withheld_in_countries                                                 TR
# withheld_ever                                                         TR
# followers_count                                                    42452
# following_count                                                       21
# signup_date                                                   2009-01-16
# first_observed                                                2017-10-02
#
#                                                                        3  \
# user_id_numfix                                                 '19813934
# user_id                                                         19813934
# screen_name                                                erdemgurkan71
# bio                    Vicdanın yansıması... Eğriye eğri... Doğruya d...
# withheld_category                                               withheld
# withheld_in_countries                                                 TR
# withheld_ever                                                         TR
# followers_count                                                    46106
# following_count                                                      150
# signup_date                                                   2009-01-31
# first_observed                                                2017-10-02
#
#                                                                        4
# user_id_numfix                                                 '22356335
# user_id                                                         22356335
# screen_name                                                   Salzig2010
# bio                    ich bin #burkaphob. im urlaub hier burkinifrei...
# withheld_category                                               withheld
# withheld_in_countries                                                 DE
# withheld_ever                                                         DE
# followers_count                                                      222
# following_count                                                      347
# signup_date                                                   2009-03-01
# first_observed                                                2017-10-02

# %%
first_observations = pd.read_csv("../data/first-observations.csv")
first_observations.head()
# Out:
#     user_id country  fetched_at
# 0  14613185      DE  2017-10-02
# 1  17232910      DE  2017-10-02
# 2  19063025      TR  2017-10-02
# 3  19813934      TR  2017-10-02
# 4  22356335      DE  2017-10-02

# %% [markdown]
# ## Step 2: Calculate basic, overall metrics

# %% [markdown]
# ### Per-country withholdings

# %% [markdown]
# Treating multi-country withholdings separately, so no double-counting:

# %%
accounts["withheld_ever"].value_counts()\
    .sort_values(ascending=False)\
    .to_frame("num_accounts")
# Out:
#               num_accounts
# TR                     721
# DE                     639
# FR                     141
# DE + FR                118
# RU                      78
# IN                      11
# BR                       2
# GB                       2
# FR + GB                  1
# DE + FR + GB             1

# %% [markdown]
# Abbreviations:
#
# - TR: Turkey
# - DE: Germany
# - FR: France
# - RU: Russia
# - IN: India
# - GB: Great Britain / United Kingdom
# - BR: Brazil

# %% [markdown]
# On a country-by-country basis, which double-counts users who've been withheld in multiple countries:

# %%
first_observations["country"].value_counts()\
    .sort_values(ascending=False)\
    .to_frame("num_accounts")
# Out:
#     num_accounts
# DE           758
# TR           721
# FR           261
# RU            78
# IN            11
# GB             4
# BR             2

# %% [markdown]
# Latest account status, as of early January:

# %%
accounts["withheld_category"].value_counts()
# Out:
# withheld           1428
# inactive            193
# media_violation      84
# not_withheld          9
# Name: withheld_category, dtype: int64

# %% [markdown]
# ## Step 3: Identify the most-followed accounts

# %% [markdown]
# Overall:

# %%
accounts_ranked = accounts\
    .assign(rank = lambda x: x["followers_count"].rank(ascending = False).astype(int))\
    .sort_values("rank")\
    .set_index("rank")[[
        "screen_name",
        "bio",
        "withheld_category",
        "withheld_in_countries",
        "withheld_ever",
        "followers_count"
    ]].fillna("")

accounts_ranked.head(10)
# Out:
#           screen_name                                                bio  \
# rank
# 1     Gurmeetramrahim  Spiritual Saint/Philanthropist/Versatile Singe...
# 2         PeriscopeCo  Explore the world through someone else's eyes....
# 3        ekremdumanli  Gazeteci/ Journalist/ [For my English account,...
# 4         Enes_Kanter  {Hizmetin Hizmetkârı} #Live4Others 🗽 #EK00 htt...
# 5          TheRedHack  Madem sonsuza dek yaşayamayacağız, o vakit ist...
# 6       sosyalpencere  #HiçDurmadanYürüyeceksiniz Sosyal Pencere #sos...
# 7      derasachasauda  Confluence of All Religions - A Socio-Spiritua...
# 8              mceutv  MC EU TV | Facebook: https://t.co/qVDj5qZNgg +...
# 9     HARAMZADELER333  Yolsuzluk İhbar: haramzadeihbar@gmail.com / Bl...
# 10       Herkul_Nagme  Bu sayfa diktatörlük tarafından Türkiye’de eng...
#
#      withheld_category withheld_in_countries withheld_ever  followers_count
# rank
# 1             withheld                    IN            IN          3564377
# 2             withheld                    TR            TR          1406417
# 3             withheld                    TR            TR           540889
# 4             withheld                    TR            TR           532832
# 5             withheld                    TR            TR           530722
# 6             withheld                    TR            TR           456502
# 7             withheld                    IN            IN           363565
# 8             withheld                    TR            TR           316495
# 9             withheld                    TR            TR           290642
# 10            withheld                    TR            TR           281023

# %% [markdown]
# Among multi-country withholdings:

# %%
accounts_ranked[
    accounts_ranked["withheld_ever"].str.contains(r" \+ ")
].head(10)
# Out:
#           screen_name                                                bio  \
# rank
# 22             AmyMek  God, Family & Country; Sports Fitness & Vegan;...
# 92     Third_Position  Third Position is a News/Journo network focusi...
# 104        Ann__Kelly  European rights activist.⛄️You are determined ...
# 105   offensive_image                    Humor so dark it should be shot
# 137   offensivemem3s_  DM me memes - offensive - everything is just f...
# 149      VeryNiceNAZI  Nationalist Anti-Zionis✞ Independent 卐 NAZI 卐 ...
# 163       zyklonbeast  Keeper of the fire ⍯ ɛquality is a false gɵɗ ⍯...
# 164             ANP14  The American Nazi Party is America's premier 2...
# 183   Nature_and_Race  National Socialism is the rebirth of mankind's...
# 191   Millennial_Matt                                  ) ) )インナーヘブン( ( (
#
#      withheld_category withheld_in_countries withheld_ever  followers_count
# rank
# 22            withheld               DE + FR       DE + FR           207125
# 92     media_violation            everywhere       DE + FR            35045
# 104           withheld               DE + FR       DE + FR            28625
# 105           inactive               DE + FR       DE + FR            27732
# 137           withheld               DE + FR       DE + FR            17591
# 149           inactive               DE + FR       DE + FR            15710
# 163           inactive               DE + FR       DE + FR            13339
# 164           inactive               DE + FR       DE + FR            13338
# 183           withheld               DE + FR       DE + FR            10757
# 191           inactive               DE + FR       DE + FR             9978

# %% [markdown]
# ## Step 4: Examine language used in profile bios

# %% [markdown]
# ### Bios mentioning "withheld"

# %%
accounts_mentioning_withheld = accounts_ranked[
    accounts_ranked["bio"].str.contains(r"withheld", case=False, na=False)
][[ "screen_name", "bio", "withheld_category"]]

print("{} accounts".format(len(accounts_mentioning_withheld)))
# Out:
# 105 accounts

# %% [markdown]
# The vast majority of these bios use a similar template:

# %%
accounts_mentioning_withheld["bio"].value_counts().head()
# Out:
# This account has been withheld in: Turkey.                                                                                                                69
# This account has been withheld in: Germany.                                                                                                               19
# This account has been withheld in: France.                                                                                                                 6
# This account is »withheld« in Germany = censored. "No one is more hated than he who speaks the truth." (Plato)                                             1
# Nach dem blocken von @NSArschloecher wird jetzt richtig gepöbelt! #FCKISLM @aiman_Mazyek ausweisen - Pro Israel 🇮🇱 WITHHELD IN GERMANY FREE IN EUROPE!     1
# Name: bio, dtype: int64

# %%
accounts_mentioning_withheld["withheld_category"].value_counts()
# Out:
# withheld           99
# inactive            5
# media_violation     1
# Name: withheld_category, dtype: int64

# %% [markdown]
# Examples:

# %%
accounts_mentioning_withheld.head()
# Out:
#           screen_name                                                bio  \
# rank
# 60      SosyalAnadolu  Your account has been withheld in Turkey in re...
# 85        ugur_aygun_         This account has been withheld in: Turkey.
# 124      Baturhanberk         This account has been withheld in: Turkey.
# 133            DEMZEM         This account has been withheld in: Turkey.
# 157   darksideoftheeg        This account has been withheld in: Germany.
#
#      withheld_category
# rank
# 60            withheld
# 85            withheld
# 124           withheld
# 133           withheld
# 157           withheld

# %% [markdown]
# ### Bios containing Nazi-related symbols

# %%
MAIN_SYMBOL_PATTERNS = [
    (r"[卐卍]", "swastikas"),
    (r"nazi(?!rah)", "nazi"),
    (r"(?<!ŞE)hitler", "Hitler"), 
]

SYMBOL_PATTERNS = MAIN_SYMBOL_PATTERNS + [
    (r"14.?88", "14/88, 1488, etc."),
    (r"14w|14 words", "14w"),
    (r"ϟϟ", "ϟϟ"),
    (r"✠", r"✠")
]

# %%
for pat, name in SYMBOL_PATTERNS:
    print("{}: {}".format(
        name,
        (
            accounts["bio"].str.contains(pat, case=False, na=False) |
            accounts["screen_name"].str.contains(pat, case=False, na=False)
        ).sum()    
    ))
# Out:
# swastikas: 18
# nazi: 61
# Hitler: 55
# 14/88, 1488, etc.: 53
# 14w: 17
# ϟϟ: 7
# ✠: 3

# %% [markdown]
# Any of the above:

# %%
main_nazi_matches = accounts[
    (accounts["bio"] + "|" + accounts["screen_name"]).str.contains(
        r"|".join(pat for pat, name in MAIN_SYMBOL_PATTERNS), 
        case=False,
        na=False
    )
]
main_nazi_matches["withheld_ever"].value_counts()
# Out:
# DE         68
# DE + FR    23
# FR         15
# TR          1
# Name: withheld_ever, dtype: int64

# %% [markdown]
# Note: Turkey match appears to be a false positive.

# %% [markdown]
# ## Step 5: Calculate dates of first-observation by country
#
# The "first observation" data indicates the first date on which BuzzFeed News noticed that a particular account was being withheld in a particular country. To be clear: These dates do __not__ not correspond to the dates on which Twitter began withholding that account in that country. Rather, the data simply says that a particular account was first withheld *on this date or earlier*.

# %%
first_obs_counts = first_observations\
    .groupby([ "fetched_at", "country" ])\
    .size()\
    .unstack()\
    .fillna(0)\
    .astype(int)

first_obs_counts
# Out:
# country     BR   DE   FR  GB  IN  RU   TR
# fetched_at
# 2017-10-02   0  399  138   3   1   5  159
# 2017-10-03   0   99   31   0   0  25  433
# 2017-10-04   0    5    2   0   1   1  115
# 2017-10-05   0    1    0   0   2   0    2
# 2017-10-10   1   53    1   0   0   0    0
# 2017-10-16   1   71   42   0   7  45   10
# 2017-10-17   0    0    1   0   0   0    0
# 2017-10-18   0    0    3   1   0   0    0
# 2017-10-19   0    1    0   0   0   0    0
# 2017-10-20   0   10    1   0   0   1    0
# 2017-10-25   0    1    3   0   0   0    0
# 2017-11-02   0    1    4   0   0   0    0
# 2017-12-07   0    2    5   0   0   0    0
# 2017-12-08   0  103   19   0   0   1    1
# 2017-12-15   0    8    6   0   0   0    1
# 2017-12-16   0    2    2   0   0   0    0
# 2017-12-18   0    1    0   0   0   0    0
# 2018-01-11   0    1    3   0   0   0    0

# %% [markdown]
# And cumulatively:

# %%
first_obs_counts.cumsum()
# Out:
# country     BR   DE   FR  GB  IN  RU   TR
# fetched_at
# 2017-10-02   0  399  138   3   1   5  159
# 2017-10-03   0  498  169   3   1  30  592
# 2017-10-04   0  503  171   3   2  31  707
# 2017-10-05   0  504  171   3   4  31  709
# 2017-10-10   1  557  172   3   4  31  709
# 2017-10-16   2  628  214   3  11  76  719
# 2017-10-17   2  628  215   3  11  76  719
# 2017-10-18   2  628  218   4  11  76  719
# 2017-10-19   2  629  218   4  11  76  719
# 2017-10-20   2  639  219   4  11  77  719
# 2017-10-25   2  640  222   4  11  77  719
# 2017-11-02   2  641  226   4  11  77  719
# 2017-12-07   2  643  231   4  11  77  719
# 2017-12-08   2  746  250   4  11  78  720
# 2017-12-15   2  754  256   4  11  78  721
# 2017-12-16   2  756  258   4  11  78  721
# 2017-12-18   2  757  258   4  11  78  721
# 2018-01-11   2  758  261   4  11  78  721

# %% [markdown]
# ---
#
# ---
#
# ---
